# %%
install.packages("https://cran.r-project.org/src/contrib/Archive/patchwork/patchwork_1.1.0.tar.gz", repos = NULL, type = "source", dependencies = TRUE)

install.packages("https://cran.r-project.org/src/contrib/Archive/broom.helpers/broom.helpers_1.4.0.tar.gz", repos = NULL, type = "source", dependencies = TRUE)

install.packages("https://cran.r-project.org/src/contrib/Archive/ggstats/ggstats_0.5.0.tar.gz", repos = NULL, type = "source", dependencies = TRUE)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Warning message in download.file(p, destfile, method, mode = "wb", ...):
# “URL 'https://cran.r-project.org/src/contrib/Archive/patchwork/patchwork_1.1.0.tar.gz': status was 'Couldn't resolve host name'”
# Error in download.file(p, destfile, method, mode = "wb", ...) :
#   cannot open URL 'https://cran.r-project.org/src/contrib/Archive/patchwork/patchwork_1.1.0.tar.gz'
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Warning message in download.file(p, destfile, method, mode = "wb", ...):
# “URL 'https://cran.r-project.org/src/contrib/Archive/broom.helpers/broom.helpers_1.4.0.tar.gz': status was 'Couldn't resolve host name'”
# Error in download.file(p, destfile, method, mode = "wb", ...) :
#   cannot open URL 'https://cran.r-project.org/src/contrib/Archive/broom.helpers/broom.helpers_1.4.0.tar.gz'
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Warning message in download.file(p, destfile, method, mode = "wb", ...):
# “URL 'https://cran.r-project.org/src/contrib/Archive/ggstats/ggstats_0.5.0.tar.gz': status was 'Couldn't resolve host name'”
# Error in download.file(p, destfile, method, mode = "wb", ...) :
#   cannot open URL 'https://cran.r-project.org/src/contrib/Archive/ggstats/ggstats_0.5.0.tar.gz'

# %%
library(datasets)
data(iris)

# %%
library(GGally)
ggpairs(iris, mapping=ggplot2::aes(colour = Species))
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
