# %%
print("Hello R!")
# Out:
# [1] "Hello R!"

# %%
print("Hello World!")
# Out:
# [1] "Hello World!"

# %%
x <- 3
y <- 4
z <- x + y
print(z)
# Out:
# [1] 7

# %%
    x <- 10
    y <- 20
    result <- y - x
    print(result)
# Out:
# [1] 10
